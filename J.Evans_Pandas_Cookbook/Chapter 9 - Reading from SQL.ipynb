# %%
import pandas as pd
import sqlite3

# %%
#establece conexión con la BD
con = sqlite3.connect("weather_2012.sqlite")

# %%
pd.read_sql?

# %%
#leemos la bd
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con)

# %%
df
# Out:
#    id            date_time  temp
# 0   1  2012-01-01 00:00:00  -1.8
# 1   2  2012-01-01 01:00:00  -1.8
# 2   3  2012-01-01 02:00:00  -1.8

# %%
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con, index_col="id")

# %%
df
# Out:
#               date_time  temp
# id
# 1   2012-01-01 00:00:00  -1.8
# 2   2012-01-01 01:00:00  -1.8
# 3   2012-01-01 02:00:00  -1.8

# %%
#índice formado por más de una columna
df = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con, index_col=["id","date_time"])

# %%
df
# Out:
#                         temp
# id date_time
# 1  2012-01-01 00:00:00  -1.8
# 2  2012-01-01 01:00:00  -1.8
# 3  2012-01-01 02:00:00  -1.8

# %%
#escribir en bd
df_weather = pd.read_csv("weather_2012.csv")

# %%
con = sqlite3.connect("test_db.sqlite")

# %%
con.execute("DROP TABLE if exists weather_2012")

# %%
df_weather.to_sql("weather_2012", con)
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
df2 = pd.read_sql("SELECT * from weather_2012 LIMIT 3", con)
df2
# Out:
#    index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0      0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1      1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2      2  2012-01-01 02:00:00      -1.8                -3.4           89
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog

# %%
df3 = pd.read_sql("SELECT * from weather_2012 ORDER BY Weather LIMIT 20", con)

# %%
df3
# Out:
#     index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0      67  2012-01-03 19:00:00     -16.9               -24.8           50
# 1     114  2012-01-05 18:00:00      -7.1               -14.4           56
# 2     115  2012-01-05 19:00:00      -9.2               -15.4           61
# 3     116  2012-01-05 20:00:00      -9.8               -15.7           62
# 4     117  2012-01-05 21:00:00      -9.0               -14.8           63
# 5     241  2012-01-11 01:00:00     -10.7               -17.8           56
# 6     242  2012-01-11 02:00:00     -12.0               -18.9           56
# 7     243  2012-01-11 03:00:00     -12.7               -19.4           57
# 8     244  2012-01-11 04:00:00     -13.4               -20.1           57
# 9     344  2012-01-15 08:00:00     -23.3               -28.5           62
# 10    351  2012-01-15 15:00:00     -15.4               -22.8           53
# 11    352  2012-01-15 16:00:00     -15.1               -22.8           52
# ...
